# %% [markdown]
# Datasheet 4.02A: Migration to and from United Kingdom by main reason for migration by citizenship groups

# %%
from databaker.framework import *
import pandas as pd

# %%
from pathlib import Path

sourceFolder = Path('in')
sourceFolder.mkdir(exist_ok=True)

# %run lib/scrape_ons.ipynb

metadata = scrape('https://www.ons.gov.uk/peoplepopulationandcommunity/populationandmigration/' \
                  'internationalmigration/datasets/ipsmainreasonformigrationbycitizenship')
metadata
# Out:
# {'about': 'International Passenger Survey detailed estimates of Long-Term International Migration: Main reason for migration by citizenship. UK, Underlying datasheet 2.',
#  'fileURL': 'https://www.ons.gov.uk/file?uri=/peoplepopulationandcommunity/populationandmigration/internationalmigration/datasets/ipsmainreasonformigrationbycitizenship/2016/underlyingdatasheet4.02ipsmainreasonformigrationbycitizenship2016.xls',
#  'mailto': 'mailto:migstatsunit@ons.gsi.gov.uk',
#  'nextRelease': datetime.date(2018, 11, 29),
#  'releaseDate': datetime.date(2017, 11, 30),
#  'title': 'International Passenger Survey\xa04.02, main\xa0reason\xa0for migration by citizenship'}

# %% [markdown]
# https://www.ons.gov.uk/file?uri=/peoplepopulationandcommunity/populationandmigration/internationalmigration/datasets/ipsmainreasonformigrationbycitizenship/2016/underlyingdatasheet4.02ipsmainreasonformigrationbycitizenship2016.xls

# %%
inputFile = sourceFolder / 'data.xls'
response = session.get(metadata['fileURL'])
# with open(inputFile, 'wb') as f:
#   f.write(response.content)
# # tab = loadxlstabs(inputFile, sheetids='Datasheet 4.02A')[0]

# %%
# response.content

# %%
xls = pd.ExcelFile(BytesIO(response.content))
df1 = pd.read_excel(xls, 'Datasheet 4.02A', header = 7)

# %%
df1
# Out:
#            Software Readable Column Label (See Notes)            Unnamed: 1  \
# 0                                              Inflow           All reasons
# 1                                                 NaN  Work related reasons
# 2                                                 NaN          Definite job
# 3                                                 NaN      Looking for work
# 4                                                 NaN      Accompany / Join
# 5                                                 NaN          Formal study
# 6                                                 NaN    Going home to live
# 7                                                 NaN         Other reasons
# 8                                                 NaN      No reason stated
# 9                                             Outflow           All reasons
# 10                                                NaN  Work related reasons
# 11                                                NaN          Definite job
# 12                                                NaN      Looking for work
# 13                                                NaN      Accompany / Join
# 14                                                NaN          Formal study
# 15                                                NaN    Going home to live
# 16                                                NaN         Other reasons
# 17                                                NaN      No reason stated
# 18                                                NaN                   NaN
# 19      Source: Office for National Statistics (ONS).                   NaN
# 20                                                NaN                   NaN
# 21                Totals may not sum due to rounding.                   NaN
# 22                                                NaN                   NaN
# 23  "z" - Not applicable, "." - No contact, "0~" -...                   NaN
# 24                                                NaN                   NaN
# 25  Migration between the UK and the Republic of I...                   NaN
# 26                                                NaN                   NaN
# 27  1  European Union estimates are for the EU15 (...                   NaN
# 28  2  Includes European Union countries as define...                   NaN
# 29  3  Includes European Union countries as define...                   NaN
# 30  4  Excludes citizens of European Union countri...                   NaN
# 31  5  From 2004 onwards, All and New Commonwealth...                   NaN
# 32                                                NaN                   NaN
# 33  Care should be taken when comparing inflow and...                   NaN
# 34                                                NaN                   NaN
# 35  This table uses 95% confidence intervals (CI) ...                   NaN
# 36                                                NaN                   NaN
# 37  Published on 30 November 2017 by the Office fo...                   NaN
# 38  © Crown copyright. You may re-use this informa...                   NaN
# 39  To view this licence, go to: http://www.nation...                   NaN
# 40  or write to the Information Policy Team, The N...                   NaN
#
#                         Row Label  CIT All EST  CIT All CI  CIT British EST  \
# 0             INFLOW, All reasons        526.6        34.4             71.7
# 1    INFLOW, Work related reasons        263.0        23.6             34.8
# 2            INFLOW, Definite job        172.3        19.0             19.1
# 3        INFLOW, Looking for work         90.6        14.0             15.7
# 4       INFLOW, Accompany or Join         83.3        12.4              6.1
# 5            INFLOW, Formal study        132.0        17.9              7.4
# 6      INFLOW, Going home to live         19.1         9.3             18.8
# 7           INFLOW, Other reasons         17.1         5.2              3.2
# 8        INFLOW, No reason stated         12.0         6.1              1.3
# 9            OUTFLOW, All reasons       -315.8        23.0           -121.0
# 10  OUTFLOW, Work related reasons       -171.0        15.1            -65.3
# 11          OUTFLOW, Definite job       -110.0        12.7            -52.5
# 12      OUTFLOW, Looking for work        -61.1         8.1            -12.8
# 13     OUTFLOW, Accompany or Join        -23.9         5.7            -14.3
# 14          OUTFLOW, Formal study        -19.8         5.6             -7.2
# 15    OUTFLOW, Going home to live        -53.2        12.7             -1.5
# 16         OUTFLOW, Other reasons        -22.8         4.9            -16.6
# 17      OUTFLOW, No reason stated        -24.9         7.2            -16.2
# 18                            NaN          NaN         NaN              NaN
# 19                            NaN          NaN         NaN              NaN
# 20                            NaN          NaN         NaN              NaN
# 21                            NaN          NaN         NaN              NaN
# 22                            NaN          NaN         NaN              NaN
# 23                            NaN          NaN         NaN              NaN
# 24                            NaN          NaN         NaN              NaN
# 25                            NaN          NaN         NaN              NaN
# 26                            NaN          NaN         NaN              NaN
# 27                            NaN          NaN         NaN              NaN
# 28                            NaN          NaN         NaN              NaN
# 29                            NaN          NaN         NaN              NaN
# 30                            NaN          NaN         NaN              NaN
# 31                            NaN          NaN         NaN              NaN
# 32                            NaN          NaN         NaN              NaN
# 33                            NaN          NaN         NaN              NaN
# 34                            NaN          NaN         NaN              NaN
# 35                            NaN          NaN         NaN              NaN
# 36                            NaN          NaN         NaN              NaN
# 37                            NaN          NaN         NaN              NaN
# 38                            NaN          NaN         NaN              NaN
# 39                            NaN          NaN         NaN              NaN
# 40                            NaN          NaN         NaN              NaN
#
#     CIT British CI  CIT Non-British EST  CIT Non-British CI  \
# 0             13.9                454.9                31.5
# 1              8.0                228.1                22.2
# 2              6.3                153.2                17.9
# 3              5.0                 74.9                13.1
# 4              3.5                 77.2                11.9
# 5              4.7                124.6                17.3
# 6              9.3                  0.3                 0.6
# 7              2.5                 13.9                 4.6
# 8              1.3                 10.7                 6.0
# 9             12.8               -194.7                19.1
# 10             9.3               -105.7                11.9
# 11             8.4                -57.5                 9.6
# 12             3.9                -48.2                 7.1
# 13             4.0                 -9.6                 4.1
# 14             2.9                -12.7                 4.8
# 15             1.6                -51.8                12.6
# 16             4.1                 -6.2                 2.7
# 17             5.8                 -8.7                 4.2
# 18             NaN                  NaN                 NaN
# 19             NaN                  NaN                 NaN
# 20             NaN                  NaN                 NaN
# 21             NaN                  NaN                 NaN
# 22             NaN                  NaN                 NaN
# 23             NaN                  NaN                 NaN
# 24             NaN                  NaN                 NaN
# 25             NaN                  NaN                 NaN
# 26             NaN                  NaN                 NaN
# 27             NaN                  NaN                 NaN
# 28             NaN                  NaN                 NaN
# 29             NaN                  NaN                 NaN
# 30             NaN                  NaN                 NaN
# 31             NaN                  NaN                 NaN
# 32             NaN                  NaN                 NaN
# 33             NaN                  NaN                 NaN
# 34             NaN                  NaN                 NaN
# 35             NaN                  NaN                 NaN
# 36             NaN                  NaN                 NaN
# 37             NaN                  NaN                 NaN
# 38             NaN                  NaN                 NaN
# 39             NaN                  NaN                 NaN
# 40             NaN                  NaN                 NaN
#
#     CIT British or British Overseas EST        ...         \
# 0                                  72.9        ...
# 1                                  36.0        ...
# 2                                  19.1        ...
# 3                                  16.9        ...
# 4                                   6.1        ...
# 5                                   7.4        ...
# 6                                  18.8        ...
# 7                                   3.2        ...
# 8                                   1.3        ...
# 9                                -121.0        ...
# 10                                -65.3        ...
# 11                                -52.5        ...
# 12                                -12.8        ...
# 13                                -14.3        ...
# 14                                 -7.2        ...
# 15                                 -1.5        ...
# 16                                -16.6        ...
# 17                                -16.2        ...
# 18                                  NaN        ...
# 19                                  NaN        ...
# 20                                  NaN        ...
# 21                                  NaN        ...
# 22                                  NaN        ...
# 23                                  NaN        ...
# 24                                  NaN        ...
# 25                                  NaN        ...
# 26                                  NaN        ...
# 27                                  NaN        ...
# 28                                  NaN        ...
# 29                                  NaN        ...
# 30                                  NaN        ...
# 31                                  NaN        ...
# 32                                  NaN        ...
# 33                                  NaN        ...
# 34                                  NaN        ...
# 35                                  NaN        ...
# 36                                  NaN        ...
# 37                                  NaN        ...
# 38                                  NaN        ...
# 39                                  NaN        ...
# 40                                  NaN        ...
#
#     CIT Sub-Saharan Africa EST  CIT Sub-Saharan Africa CI   \
# 0                         21.3                         7.7
# 1                          4.6                         2.6
# 2                          2.1                         1.4
# 3                          2.6                         2.3
# 4                          7.6                           4
# 5                          8.6                           6
# 6                            .                           .
# 7                            .                           .
# 8                          0.5                         0.7
# 9                         -3.7                           3
# 10                        -3.1                         2.9
# 11                        -1.9                         2.7
# 12                        -1.2                           1
# 13                           .                           .
# 14                        -0.4                         0.5
# 15                        -0.3                         0.6
# 16                           .                           .
# 17                           .                           .
# 18                         NaN                         NaN
# 19                         NaN                         NaN
# 20                         NaN                         NaN
# 21                         NaN                         NaN
# 22                         NaN                         NaN
# 23                         NaN                         NaN
# 24                         NaN                         NaN
# 25                         NaN                         NaN
# 26                         NaN                         NaN
# 27                         NaN                         NaN
# 28                         NaN                         NaN
# 29                         NaN                         NaN
# 30                         NaN                         NaN
# 31                         NaN                         NaN
# 32                         NaN                         NaN
# 33                         NaN                         NaN
# 34                         NaN                         NaN
# 35                         NaN                         NaN
# 36                         NaN                         NaN
# 37                         NaN                         NaN
# 38                         NaN                         NaN
# 39                         NaN                         NaN
# 40                         NaN                         NaN
#
#     CIT North America EST  CIT North America CI   \
# 0                    20.3                      5
# 1                     7.8                    2.8
# 2                     6.6                    2.6
# 3                     1.1                      1
# 4                     4.4                    2.4
# 5                     6.2                    2.9
# 6                       .                      .
# 7                     1.8                    1.6
# 8                     0.2                    0.3
# 9                   -16.1                    5.5
# 10                   -8.8                    3.9
# 11                   -5.4                    3.4
# 12                   -3.4                    1.8
# 13                   -3.8                      3
# 14                   -0.9                      1
# 15                   -2.3                    2.2
# 16                   -0.1                    0.2
# 17                   -0.1                    0.3
# 18                    NaN                    NaN
# 19                    NaN                    NaN
# 20                    NaN                    NaN
# 21                    NaN                    NaN
# 22                    NaN                    NaN
# 23                    NaN                    NaN
# 24                    NaN                    NaN
# 25                    NaN                    NaN
# 26                    NaN                    NaN
# 27                    NaN                    NaN
# 28                    NaN                    NaN
# 29                    NaN                    NaN
# 30                    NaN                    NaN
# 31                    NaN                    NaN
# 32                    NaN                    NaN
# 33                    NaN                    NaN
# 34                    NaN                    NaN
# 35                    NaN                    NaN
# 36                    NaN                    NaN
# 37                    NaN                    NaN
# 38                    NaN                    NaN
# 39                    NaN                    NaN
# 40                    NaN                    NaN
#
#     CIT Central and South America EST  CIT Central and South America CI   \
# 0                                13.7                                6.6
# 1                                 3.5                                2.9
# 2                                 2.3                                2.4
# 3                                 1.2                                1.7
# 4                                 2.5                                  2
# 5                                 7.4                                5.5
# 6                                   .                                  .
# 7                                   .                                  .
# 8                                 0.2                                0.4
# 9                                -3.5                                1.8
# 10                               -2.9                                1.7
# 11                                 -1                                0.8
# 12                                 -2                                1.5
# 13                                  .                                  .
# 14                               -0.3                                0.4
# 15                                  .                                  .
# 16                               -0.2                                0.3
# 17                                  .                                  .
# 18                                NaN                                NaN
# 19                                NaN                                NaN
# 20                                NaN                                NaN
# 21                                NaN                                NaN
# 22                                NaN                                NaN
# 23                                NaN                                NaN
# 24                                NaN                                NaN
# 25                                NaN                                NaN
# 26                                NaN                                NaN
# 27                                NaN                                NaN
# 28                                NaN                                NaN
# 29                                NaN                                NaN
# 30                                NaN                                NaN
# 31                                NaN                                NaN
# 32                                NaN                                NaN
# 33                                NaN                                NaN
# 34                                NaN                                NaN
# 35                                NaN                                NaN
# 36                                NaN                                NaN
# 37                                NaN                                NaN
# 38                                NaN                                NaN
# 39                                NaN                                NaN
# 40                                NaN                                NaN
#
#     CIT Oceania EST CIT Oceania CI  CIT Stateless EST CIT Stateless CI
# 0              16.7             4.3                 .                 .
# 1              13.7               4                 .                 .
# 2               5.6             2.4                 .                 .
# 3               8.1             3.2                 .                 .
# 4               0.8             0.8                 .                 .
# 5               0.3             0.5                 .                 .
# 6                 .               .                 .                 .
# 7               1.8             1.1                 .                 .
# 8                 0             0.1                 .                 .
# 9              -8.9             2.8                 .                 .
# 10             -5.8             2.2                 .                 .
# 11             -3.1             1.7                 .                 .
# 12             -2.8             1.3                 .                 .
# 13             -0.2             0.4                 .                 .
# 14             -0.4             0.7                 .                 .
# 15               -1             0.9                 .                 .
# 16             -1.2             1.4                 .                 .
# 17             -0.3             0.4                 .                 .
# 18              NaN             NaN               NaN               NaN
# 19              NaN             NaN               NaN               NaN
# 20              NaN             NaN               NaN               NaN
# 21              NaN             NaN               NaN               NaN
# 22              NaN             NaN               NaN               NaN
# 23              NaN             NaN               NaN               NaN
# 24              NaN             NaN               NaN               NaN
# 25              NaN             NaN               NaN               NaN
# 26              NaN             NaN               NaN               NaN
# 27              NaN             NaN               NaN               NaN
# 28              NaN             NaN               NaN               NaN
# 29              NaN             NaN               NaN               NaN
# 30              NaN             NaN               NaN               NaN
# 31              NaN             NaN               NaN               NaN
# 32              NaN             NaN               NaN               NaN
# 33              NaN             NaN               NaN               NaN
# 34              NaN             NaN               NaN               NaN
# 35              NaN             NaN               NaN               NaN
# 36              NaN             NaN               NaN               NaN
# 37              NaN             NaN               NaN               NaN
# 38              NaN             NaN               NaN               NaN
# 39              NaN             NaN               NaN               NaN
# 40              NaN             NaN               NaN               NaN
#
# [41 rows x 63 columns]

# %%
observations = df1.iloc[:, 2:]
observations.head()
# Out:
#                       Row Label  CIT All EST  CIT All CI  CIT British EST  \
# 0           INFLOW, All reasons        526.6        34.4             71.7
# 1  INFLOW, Work related reasons        263.0        23.6             34.8
# 2          INFLOW, Definite job        172.3        19.0             19.1
# 3      INFLOW, Looking for work         90.6        14.0             15.7
# 4     INFLOW, Accompany or Join         83.3        12.4              6.1
#
#    CIT British CI  CIT Non-British EST  CIT Non-British CI  \
# 0            13.9                454.9                31.5
# 1             8.0                228.1                22.2
# 2             6.3                153.2                17.9
# 3             5.0                 74.9                13.1
# 4             3.5                 77.2                11.9
#
#    CIT British or British Overseas EST  CIT British or British Overseas CI  \
# 0                                 72.9                                14.1
# 1                                 36.0                                 8.3
# 2                                 19.1                                 6.3
# 3                                 16.9                                 5.5
# 4                                  6.1                                 3.5
#
#    CIT Not British or British Overseas EST        ...          \
# 0                                    453.7        ...
# 1                                    226.9        ...
# 2                                    153.2        ...
# 3                                     73.7        ...
# 4                                     77.2        ...
#
#    CIT Sub-Saharan Africa EST  CIT Sub-Saharan Africa CI   \
# 0                        21.3                         7.7
# 1                         4.6                         2.6
# 2                         2.1                         1.4
# 3                         2.6                         2.3
# 4                         7.6                           4
#
#    CIT North America EST  CIT North America CI   \
# 0                   20.3                      5
# 1                    7.8                    2.8
# 2                    6.6                    2.6
# 3                    1.1                      1
# 4                    4.4                    2.4
#
#    CIT Central and South America EST CIT Central and South America CI   \
# 0                               13.7                               6.6
# 1                                3.5                               2.9
# 2                                2.3                               2.4
# 3                                1.2                               1.7
# 4                                2.5                                 2
#
#   CIT Oceania EST CIT Oceania CI  CIT Stateless EST  CIT Stateless CI
# 0            16.7             4.3                 .                  .
# 1            13.7               4                 .                  .
# 2             5.6             2.4                 .                  .
# 3             8.1             3.2                 .                  .
# 4             0.8             0.8                 .                  .
#
# [5 rows x 61 columns]

# %%
new_table = pd.melt(observations,
                       ["Row Label"],
                       var_name="Column label",
                       value_name="Value")

# %%
new_table.head(50)
# Out:
#                         Row Label Column label  Value
# 0             INFLOW, All reasons  CIT All EST  526.6
# 1    INFLOW, Work related reasons  CIT All EST    263
# 2            INFLOW, Definite job  CIT All EST  172.3
# 3        INFLOW, Looking for work  CIT All EST   90.6
# 4       INFLOW, Accompany or Join  CIT All EST   83.3
# 5            INFLOW, Formal study  CIT All EST    132
# 6      INFLOW, Going home to live  CIT All EST   19.1
# 7           INFLOW, Other reasons  CIT All EST   17.1
# 8        INFLOW, No reason stated  CIT All EST     12
# 9            OUTFLOW, All reasons  CIT All EST -315.8
# 10  OUTFLOW, Work related reasons  CIT All EST   -171
# 11          OUTFLOW, Definite job  CIT All EST   -110
# 12      OUTFLOW, Looking for work  CIT All EST  -61.1
# 13     OUTFLOW, Accompany or Join  CIT All EST  -23.9
# 14          OUTFLOW, Formal study  CIT All EST  -19.8
# 15    OUTFLOW, Going home to live  CIT All EST  -53.2
# 16         OUTFLOW, Other reasons  CIT All EST  -22.8
# 17      OUTFLOW, No reason stated  CIT All EST  -24.9
# 18                            NaN  CIT All EST    NaN
# 19                            NaN  CIT All EST    NaN
# 20                            NaN  CIT All EST    NaN
# 21                            NaN  CIT All EST    NaN
# 22                            NaN  CIT All EST    NaN
# 23                            NaN  CIT All EST    NaN
# 24                            NaN  CIT All EST    NaN
# 25                            NaN  CIT All EST    NaN
# 26                            NaN  CIT All EST    NaN
# 27                            NaN  CIT All EST    NaN
# 28                            NaN  CIT All EST    NaN
# 29                            NaN  CIT All EST    NaN
# 30                            NaN  CIT All EST    NaN
# 31                            NaN  CIT All EST    NaN
# 32                            NaN  CIT All EST    NaN
# 33                            NaN  CIT All EST    NaN
# 34                            NaN  CIT All EST    NaN
# 35                            NaN  CIT All EST    NaN
# 36                            NaN  CIT All EST    NaN
# 37                            NaN  CIT All EST    NaN
# 38                            NaN  CIT All EST    NaN
# 39                            NaN  CIT All EST    NaN
# 40                            NaN  CIT All EST    NaN
# 41            INFLOW, All reasons   CIT All CI   34.4
# 42   INFLOW, Work related reasons   CIT All CI   23.6
# 43           INFLOW, Definite job   CIT All CI     19
# 44       INFLOW, Looking for work   CIT All CI     14
# 45      INFLOW, Accompany or Join   CIT All CI   12.4
# 46           INFLOW, Formal study   CIT All CI   17.9
# 47     INFLOW, Going home to live   CIT All CI    9.3
# 48          INFLOW, Other reasons   CIT All CI    5.2
# 49       INFLOW, No reason stated   CIT All CI    6.1

# %%
new_table.shape
# Out:
# (2460, 3)

# %%
new_table.dropna(inplace=True)

# %%
new_table = new_table[new_table['Value'] != '.']

# %%
new_table = new_table[new_table['Value'] != '0']

# %%
new_table.head(50)
# Out:
#                         Row Label     Column label  Value
# 0             INFLOW, All reasons      CIT All EST  526.6
# 1    INFLOW, Work related reasons      CIT All EST    263
# 2            INFLOW, Definite job      CIT All EST  172.3
# 3        INFLOW, Looking for work      CIT All EST   90.6
# 4       INFLOW, Accompany or Join      CIT All EST   83.3
# 5            INFLOW, Formal study      CIT All EST    132
# 6      INFLOW, Going home to live      CIT All EST   19.1
# 7           INFLOW, Other reasons      CIT All EST   17.1
# 8        INFLOW, No reason stated      CIT All EST     12
# 9            OUTFLOW, All reasons      CIT All EST -315.8
# 10  OUTFLOW, Work related reasons      CIT All EST   -171
# 11          OUTFLOW, Definite job      CIT All EST   -110
# 12      OUTFLOW, Looking for work      CIT All EST  -61.1
# 13     OUTFLOW, Accompany or Join      CIT All EST  -23.9
# 14          OUTFLOW, Formal study      CIT All EST  -19.8
# 15    OUTFLOW, Going home to live      CIT All EST  -53.2
# 16         OUTFLOW, Other reasons      CIT All EST  -22.8
# 17      OUTFLOW, No reason stated      CIT All EST  -24.9
# 41            INFLOW, All reasons       CIT All CI   34.4
# 42   INFLOW, Work related reasons       CIT All CI   23.6
# 43           INFLOW, Definite job       CIT All CI     19
# 44       INFLOW, Looking for work       CIT All CI     14
# 45      INFLOW, Accompany or Join       CIT All CI   12.4
# 46           INFLOW, Formal study       CIT All CI   17.9
# 47     INFLOW, Going home to live       CIT All CI    9.3
# 48          INFLOW, Other reasons       CIT All CI    5.2
# 49       INFLOW, No reason stated       CIT All CI    6.1
# 50           OUTFLOW, All reasons       CIT All CI     23
# 51  OUTFLOW, Work related reasons       CIT All CI   15.1
# 52          OUTFLOW, Definite job       CIT All CI   12.7
# 53      OUTFLOW, Looking for work       CIT All CI    8.1
# 54     OUTFLOW, Accompany or Join       CIT All CI    5.7
# 55          OUTFLOW, Formal study       CIT All CI    5.6
# 56    OUTFLOW, Going home to live       CIT All CI   12.7
# 57         OUTFLOW, Other reasons       CIT All CI    4.9
# 58      OUTFLOW, No reason stated       CIT All CI    7.2
# 82            INFLOW, All reasons  CIT British EST   71.7
# 83   INFLOW, Work related reasons  CIT British EST   34.8
# 84           INFLOW, Definite job  CIT British EST   19.1
# 85       INFLOW, Looking for work  CIT British EST   15.7
# 86      INFLOW, Accompany or Join  CIT British EST    6.1
# 87           INFLOW, Formal study  CIT British EST    7.4
# 88     INFLOW, Going home to live  CIT British EST   18.8
# 89          INFLOW, Other reasons  CIT British EST    3.2
# 90       INFLOW, No reason stated  CIT British EST    1.3
# 91           OUTFLOW, All reasons  CIT British EST   -121
# 92  OUTFLOW, Work related reasons  CIT British EST  -65.3
# 93          OUTFLOW, Definite job  CIT British EST  -52.5
# 94      OUTFLOW, Looking for work  CIT British EST  -12.8
# 95     OUTFLOW, Accompany or Join  CIT British EST  -14.3

# %%
new_table.count()
# Out:
# Row Label       964
# Column label    964
# Value           964
# dtype: int64

# %%
# sourceFilename = 'column-labels-revised.csv'
# sourceFile = sourceFolder / sourceFilename
# sourceUrl = 'https://drive.google.com/uc?export=download&id=1G3tiDCLxNxyrQ95W94DXsHNMqBxv45NX'

# if not (sourceFile.exists() and sourceFile.is_file()):
#     response = requests.get(sourceUrl)
#     with open(sourceFile, 'wb') as f:
#         f.write(response.content)

# columns = pd.read_csv(sourceFile)

# %%
# sourceFilename = 'row-labels-revised.csv'
# sourceFile = sourceFolder / sourceFilename
# sourceUrl = 'https://drive.google.com/uc?export=download&id=1baA0s5L1PdbK0VPWgNde70yjGFSAeZpa'

# if not (sourceFile.exists() and sourceFile.is_file()):
#     response = requests.get(sourceUrl)
#     with open(sourceFile, 'wb') as f:
#         f.write(response.content)

# rows = pd.read_csv(sourceFile)

# %%
# columns.head()

# %%
# rows.head()

# %%
# new_table = pd.merge(new_table, columns, how = 'left', left_on = 'Column label', right_on = 'Original.Label')

# %%
# new_table.head()

# %%
# new_table = pd.merge(new_table, rows, how = 'left', left_on = 'Row Label', right_on = 'original')

# %%
new_table.head()
# Out:
#                       Row Label Column label  Value
# 0           INFLOW, All reasons  CIT All EST  526.6
# 1  INFLOW, Work related reasons  CIT All EST    263
# 2          INFLOW, Definite job  CIT All EST  172.3
# 3      INFLOW, Looking for work  CIT All EST   90.6
# 4     INFLOW, Accompany or Join  CIT All EST   83.3

# %%
new_table['Geography'] = 'K02000001'
new_table['Unit'] = 'People (thousands)'
new_table['Measure Type'] = 'Count'
new_table['Year'] = '2016'
new_table.tail()
# Out:
#                         Row Label     Column label Value  Geography  \
# 2350   OUTFLOW, Accompany or Join  CIT Oceania CI    0.4  K02000001
# 2351        OUTFLOW, Formal study  CIT Oceania CI    0.7  K02000001
# 2352  OUTFLOW, Going home to live  CIT Oceania CI    0.9  K02000001
# 2353       OUTFLOW, Other reasons  CIT Oceania CI    1.4  K02000001
# 2354    OUTFLOW, No reason stated  CIT Oceania CI    0.4  K02000001
#
#                     Unit Measure Type  Year
# 2350  People (thousands)        Count  2016
# 2351  People (thousands)        Count  2016
# 2352  People (thousands)        Count  2016
# 2353  People (thousands)        Count  2016
# 2354  People (thousands)        Count  2016

# %%
new_table.dtypes
# Out:
# Row Label       object
# Column label    object
# Value           object
# Geography       object
# Unit            object
# Measure Type    object
# Year            object
# dtype: object

# %%
new_table['Value'] = new_table['Value'].astype(int)

# %%
new_table['Year'] = new_table['Year'].astype(int)

# %%
new_table.count()
# Out:
# Row Label       964
# Column label    964
# Value           964
# Geography       964
# Unit            964
# Measure Type    964
# Year            964
# dtype: int64

# %%
new_table.head(5)
# Out:
#                       Row Label Column label  Value  Geography  \
# 0           INFLOW, All reasons  CIT All EST    526  K02000001
# 1  INFLOW, Work related reasons  CIT All EST    263  K02000001
# 2          INFLOW, Definite job  CIT All EST    172  K02000001
# 3      INFLOW, Looking for work  CIT All EST     90  K02000001
# 4     INFLOW, Accompany or Join  CIT All EST     83  K02000001
#
#                  Unit Measure Type  Year
# 0  People (thousands)        Count  2016
# 1  People (thousands)        Count  2016
# 2  People (thousands)        Count  2016
# 3  People (thousands)        Count  2016
# 4  People (thousands)        Count  2016

# %%
new_table = new_table[['Geography','Year','Row Label','Column label','Measure Type','Value','Unit']]

# %%
new_table
# Out:
#       Geography  Year                      Row Label     Column label  \
# 0     K02000001  2016            INFLOW, All reasons      CIT All EST
# 1     K02000001  2016   INFLOW, Work related reasons      CIT All EST
# 2     K02000001  2016           INFLOW, Definite job      CIT All EST
# 3     K02000001  2016       INFLOW, Looking for work      CIT All EST
# 4     K02000001  2016      INFLOW, Accompany or Join      CIT All EST
# 5     K02000001  2016           INFLOW, Formal study      CIT All EST
# 6     K02000001  2016     INFLOW, Going home to live      CIT All EST
# 7     K02000001  2016          INFLOW, Other reasons      CIT All EST
# 8     K02000001  2016       INFLOW, No reason stated      CIT All EST
# 9     K02000001  2016           OUTFLOW, All reasons      CIT All EST
# 10    K02000001  2016  OUTFLOW, Work related reasons      CIT All EST
# 11    K02000001  2016          OUTFLOW, Definite job      CIT All EST
# 12    K02000001  2016      OUTFLOW, Looking for work      CIT All EST
# 13    K02000001  2016     OUTFLOW, Accompany or Join      CIT All EST
# 14    K02000001  2016          OUTFLOW, Formal study      CIT All EST
# 15    K02000001  2016    OUTFLOW, Going home to live      CIT All EST
# 16    K02000001  2016         OUTFLOW, Other reasons      CIT All EST
# 17    K02000001  2016      OUTFLOW, No reason stated      CIT All EST
# 41    K02000001  2016            INFLOW, All reasons       CIT All CI
# 42    K02000001  2016   INFLOW, Work related reasons       CIT All CI
# 43    K02000001  2016           INFLOW, Definite job       CIT All CI
# 44    K02000001  2016       INFLOW, Looking for work       CIT All CI
# 45    K02000001  2016      INFLOW, Accompany or Join       CIT All CI
# 46    K02000001  2016           INFLOW, Formal study       CIT All CI
# 47    K02000001  2016     INFLOW, Going home to live       CIT All CI
# 48    K02000001  2016          INFLOW, Other reasons       CIT All CI
# 49    K02000001  2016       INFLOW, No reason stated       CIT All CI
# 50    K02000001  2016           OUTFLOW, All reasons       CIT All CI
# 51    K02000001  2016  OUTFLOW, Work related reasons       CIT All CI
# 52    K02000001  2016          OUTFLOW, Definite job       CIT All CI
# ...         ...   ...                            ...              ...
# 2300  K02000001  2016      INFLOW, Accompany or Join  CIT Oceania EST
# 2301  K02000001  2016           INFLOW, Formal study  CIT Oceania EST
# 2303  K02000001  2016          INFLOW, Other reasons  CIT Oceania EST
# 2304  K02000001  2016       INFLOW, No reason stated  CIT Oceania EST
# 2305  K02000001  2016           OUTFLOW, All reasons  CIT Oceania EST
# 2306  K02000001  2016  OUTFLOW, Work related reasons  CIT Oceania EST
# 2307  K02000001  2016          OUTFLOW, Definite job  CIT Oceania EST
# 2308  K02000001  2016      OUTFLOW, Looking for work  CIT Oceania EST
# 2309  K02000001  2016     OUTFLOW, Accompany or Join  CIT Oceania EST
# 2310  K02000001  2016          OUTFLOW, Formal study  CIT Oceania EST
# 2311  K02000001  2016    OUTFLOW, Going home to live  CIT Oceania EST
# 2312  K02000001  2016         OUTFLOW, Other reasons  CIT Oceania EST
# 2313  K02000001  2016      OUTFLOW, No reason stated  CIT Oceania EST
# 2337  K02000001  2016            INFLOW, All reasons  CIT Oceania CI
# 2338  K02000001  2016   INFLOW, Work related reasons  CIT Oceania CI
# 2339  K02000001  2016           INFLOW, Definite job  CIT Oceania CI
# 2340  K02000001  2016       INFLOW, Looking for work  CIT Oceania CI
# 2341  K02000001  2016      INFLOW, Accompany or Join  CIT Oceania CI
# 2342  K02000001  2016           INFLOW, Formal study  CIT Oceania CI
# 2344  K02000001  2016          INFLOW, Other reasons  CIT Oceania CI
# 2345  K02000001  2016       INFLOW, No reason stated  CIT Oceania CI
# 2346  K02000001  2016           OUTFLOW, All reasons  CIT Oceania CI
# 2347  K02000001  2016  OUTFLOW, Work related reasons  CIT Oceania CI
# 2348  K02000001  2016          OUTFLOW, Definite job  CIT Oceania CI
# 2349  K02000001  2016      OUTFLOW, Looking for work  CIT Oceania CI
# 2350  K02000001  2016     OUTFLOW, Accompany or Join  CIT Oceania CI
# 2351  K02000001  2016          OUTFLOW, Formal study  CIT Oceania CI
# 2352  K02000001  2016    OUTFLOW, Going home to live  CIT Oceania CI
# 2353  K02000001  2016         OUTFLOW, Other reasons  CIT Oceania CI
# 2354  K02000001  2016      OUTFLOW, No reason stated  CIT Oceania CI
#
#      Measure Type  Value                Unit
# 0           Count    526  People (thousands)
# 1           Count    263  People (thousands)
# 2           Count    172  People (thousands)
# 3           Count     90  People (thousands)
# 4           Count     83  People (thousands)
# 5           Count    132  People (thousands)
# 6           Count     19  People (thousands)
# 7           Count     17  People (thousands)
# 8           Count     12  People (thousands)
# 9           Count   -315  People (thousands)
# 10          Count   -171  People (thousands)
# 11          Count   -110  People (thousands)
# 12          Count    -61  People (thousands)
# 13          Count    -23  People (thousands)
# 14          Count    -19  People (thousands)
# 15          Count    -53  People (thousands)
# 16          Count    -22  People (thousands)
# 17          Count    -24  People (thousands)
# 41          Count     34  People (thousands)
# 42          Count     23  People (thousands)
# 43          Count     19  People (thousands)
# 44          Count     14  People (thousands)
# 45          Count     12  People (thousands)
# 46          Count     17  People (thousands)
# 47          Count      9  People (thousands)
# 48          Count      5  People (thousands)
# 49          Count      6  People (thousands)
# 50          Count     23  People (thousands)
# 51          Count     15  People (thousands)
# 52          Count     12  People (thousands)
# ...           ...    ...                 ...
# 2300        Count      0  People (thousands)
# 2301        Count      0  People (thousands)
# 2303        Count      1  People (thousands)
# 2304        Count      0  People (thousands)
# 2305        Count     -8  People (thousands)
# 2306        Count     -5  People (thousands)
# 2307        Count     -3  People (thousands)
# 2308        Count     -2  People (thousands)
# 2309        Count      0  People (thousands)
# 2310        Count      0  People (thousands)
# 2311        Count     -1  People (thousands)
# 2312        Count     -1  People (thousands)
# 2313        Count      0  People (thousands)
# 2337        Count      4  People (thousands)
# 2338        Count      4  People (thousands)
# 2339        Count      2  People (thousands)
# 2340        Count      3  People (thousands)
# 2341        Count      0  People (thousands)
# 2342        Count      0  People (thousands)
# 2344        Count      1  People (thousands)
# 2345        Count      0  People (thousands)
# 2346        Count      2  People (thousands)
# 2347        Count      2  People (thousands)
# 2348        Count      1  People (thousands)
# 2349        Count      1  People (thousands)
# 2350        Count      0  People (thousands)
# 2351        Count      0  People (thousands)
# 2352        Count      0  People (thousands)
# 2353        Count      1  People (thousands)
# 2354        Count      0  People (thousands)
#
# [964 rows x 7 columns]

# %%
destinationFolder = Path('out')
destinationFolder.mkdir(exist_ok=True, parents=True)

new_table.to_csv(destinationFolder / ('tidydata4.02A.csv'), index = False)

# %%
writeMetadata(metadata, 'ONS-LTIM-Passenger-survey-4.02A', 'Migration')

# %%
new_table.count()
# Out:
# Geography       964
# Year            964
# Row Label       964
# Column label    964
# Measure Type    964
# Value           964
# Unit            964
# dtype: int64
