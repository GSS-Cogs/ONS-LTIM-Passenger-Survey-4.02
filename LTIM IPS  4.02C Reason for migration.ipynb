# %% [markdown]
# Datasheet 4.02C: Migration to and from United Kingdom by main reason for migration by citizenship groups

# %%
from databaker.framework import *
import pandas as pd

# %%
from pathlib import Path

sourceFolder = Path('in')
sourceFolder.mkdir(exist_ok=True)

# %run lib/scrape_ons.ipynb

metadata = scrape('https://www.ons.gov.uk/peoplepopulationandcommunity/populationandmigration/' \
                  'internationalmigration/datasets/ipsmainreasonformigrationbycitizenship')
metadata
# Out:
# {'about': 'International Passenger Survey detailed estimates of Long-Term International Migration: Main reason for migration by citizenship. UK, Underlying datasheet 2.',
#  'fileURL': 'https://www.ons.gov.uk/file?uri=/peoplepopulationandcommunity/populationandmigration/internationalmigration/datasets/ipsmainreasonformigrationbycitizenship/2016/underlyingdatasheet4.02ipsmainreasonformigrationbycitizenship2016.xls',
#  'mailto': 'mailto:migstatsunit@ons.gsi.gov.uk',
#  'nextRelease': datetime.date(2018, 11, 29),
#  'releaseDate': datetime.date(2017, 11, 30),
#  'title': 'International Passenger Survey\xa04.02, main\xa0reason\xa0for migration by citizenship'}

# %% [markdown]
# https://www.ons.gov.uk/file?uri=/peoplepopulationandcommunity/populationandmigration/internationalmigration/datasets/ipsmainreasonformigrationbycitizenship/2016/underlyingdatasheet4.02ipsmainreasonformigrationbycitizenship2016.xls

# %%
inputFile = sourceFolder / 'data.xls'
response = session.get(metadata['fileURL'])
# with open(inputFile, 'wb') as f:
#   f.write(response.content)
# # tab = loadxlstabs(inputFile, sheetids='Datasheet 4.02C')[0]

# %%
# response.content

# %%
xls = pd.ExcelFile(BytesIO(response.content))
df1 = pd.read_excel(xls, 'Datasheet 4.02C', header = 7)

# %%
df1
# Out:
#            Software Readable Column Label (See Notes)            Unnamed: 1  \
# 0                                              Inflow           All reasons
# 1                                                 NaN  Work related reasons
# 2                                                 NaN          Definite job
# 3                                                 NaN      Looking for work
# 4                                                 NaN      Accompany / Join
# 5                                                 NaN          Formal study
# 6                                                 NaN    Going home to live
# 7                                                 NaN         Other reasons
# 8                                                 NaN      No reason stated
# 9                                             Outflow           All reasons
# 10                                                NaN  Work related reasons
# 11                                                NaN          Definite job
# 12                                                NaN      Looking for work
# 13                                                NaN      Accompany / Join
# 14                                                NaN          Formal study
# 15                                                NaN    Going home to live
# 16                                                NaN         Other reasons
# 17                                                NaN      No reason stated
# 18                                                NaN                   NaN
# 19      Source: Office for National Statistics (ONS).                   NaN
# 20                                                NaN                   NaN
# 21                Totals may not sum due to rounding.                   NaN
# 22                                                NaN                   NaN
# 23  "z" - Not applicable, "." - No contact, "0~" -...                   NaN
# 24                                                NaN                   NaN
# 25  Migration between the UK and the Republic of I...                   NaN
# 26                                                NaN                   NaN
# 27  Citizenships for which there were no contacts ...                   NaN
# 28                                                NaN                   NaN
# 29  Care should be taken when comparing inflow and...                   NaN
# 30                                                NaN                   NaN
# 31  This table uses 95% confidence intervals (CI) ...                   NaN
# 32                                                NaN                   NaN
# 33  Published on 30 November 2017 by the Office fo...                   NaN
# 34  © Crown copyright. You may re-use this informa...                   NaN
# 35  To view this licence, go to: http://www.nation...                   NaN
# 36  or write to the Information Policy Team, The N...                   NaN
#
#                         Row Label  CIT All EST  CIT All CI CIT Germany EST  \
# 0             INFLOW, All reasons        526.6        34.4             9.1
# 1    INFLOW, Work related reasons        263.0        23.6             4.3
# 2            INFLOW, Definite job        172.3        19.0             3.2
# 3        INFLOW, Looking for work         90.6        14.0             1.1
# 4       INFLOW, Accompany or Join         83.3        12.4             0.7
# 5            INFLOW, Formal study        132.0        17.9             2.5
# 6      INFLOW, Going home to live         19.1         9.3               .
# 7           INFLOW, Other reasons         17.1         5.2             1.1
# 8        INFLOW, No reason stated         12.0         6.1             0.5
# 9            OUTFLOW, All reasons       -315.8        23.0            -7.8
# 10  OUTFLOW, Work related reasons       -171.0        15.1            -2.1
# 11          OUTFLOW, Definite job       -110.0        12.7               .
# 12      OUTFLOW, Looking for work        -61.1         8.1            -2.1
# 13     OUTFLOW, Accompany or Join        -23.9         5.7            -0.4
# 14          OUTFLOW, Formal study        -19.8         5.6            -2.8
# 15    OUTFLOW, Going home to live        -53.2        12.7              -2
# 16         OUTFLOW, Other reasons        -22.8         4.9               .
# 17      OUTFLOW, No reason stated        -24.9         7.2            -0.4
# 18                            NaN          NaN         NaN             NaN
# 19                            NaN          NaN         NaN             NaN
# 20                            NaN          NaN         NaN             NaN
# 21                            NaN          NaN         NaN             NaN
# 22                            NaN          NaN         NaN             NaN
# 23                            NaN          NaN         NaN             NaN
# 24                            NaN          NaN         NaN             NaN
# 25                            NaN          NaN         NaN             NaN
# 26                            NaN          NaN         NaN             NaN
# 27                            NaN          NaN         NaN             NaN
# 28                            NaN          NaN         NaN             NaN
# 29                            NaN          NaN         NaN             NaN
# 30                            NaN          NaN         NaN             NaN
# 31                            NaN          NaN         NaN             NaN
# 32                            NaN          NaN         NaN             NaN
# 33                            NaN          NaN         NaN             NaN
# 34                            NaN          NaN         NaN             NaN
# 35                            NaN          NaN         NaN             NaN
# 36                            NaN          NaN         NaN             NaN
#
#    CIT Germany CI CIT Ghana EST CIT Ghana CI CIT Greece EST      ...       \
# 0             3.7           0.7          0.6            4.8      ...
# 1             2.5           0.2          0.3            2.4      ...
# 2               2           0.2          0.3            1.6      ...
# 3             1.4             .            .            0.8      ...
# 4             0.8           0.4          0.4            0.6      ...
# 5               2           0.1          0.2            1.7      ...
# 6               .             .            .              .      ...
# 7             1.5             .            .              .      ...
# 8             0.9             .            .              .      ...
# 9             4.3             .            .           -0.8      ...
# 10            1.8             .            .           -0.5      ...
# 11              .             .            .           -0.1      ...
# 12            1.8             .            .           -0.4      ...
# 13            0.5             .            .              .      ...
# 14            2.8             .            .           -0.2      ...
# 15            2.5             .            .              .      ...
# 16              .             .            .              .      ...
# 17            0.6             .            .              .      ...
# 18            NaN           NaN          NaN            NaN      ...
# 19            NaN           NaN          NaN            NaN      ...
# 20            NaN           NaN          NaN            NaN      ...
# 21            NaN           NaN          NaN            NaN      ...
# 22            NaN           NaN          NaN            NaN      ...
# 23            NaN           NaN          NaN            NaN      ...
# 24            NaN           NaN          NaN            NaN      ...
# 25            NaN           NaN          NaN            NaN      ...
# 26            NaN           NaN          NaN            NaN      ...
# 27            NaN           NaN          NaN            NaN      ...
# 28            NaN           NaN          NaN            NaN      ...
# 29            NaN           NaN          NaN            NaN      ...
# 30            NaN           NaN          NaN            NaN      ...
# 31            NaN           NaN          NaN            NaN      ...
# 32            NaN           NaN          NaN            NaN      ...
# 33            NaN           NaN          NaN            NaN      ...
# 34            NaN           NaN          NaN            NaN      ...
# 35            NaN           NaN          NaN            NaN      ...
# 36            NaN           NaN          NaN            NaN      ...
#
#    CIT Nepal EST CIT Nepal CI CIT Netherlands EST CIT Netherlands CI  \
# 0            1.4          0.8                   6                4.8
# 1            0.1          0.2                 3.2                2.8
# 2            0.1          0.2                 2.2                2.3
# 3              .            .                 1.1                1.5
# 4              1          0.7                 0.2                0.3
# 5              .            .                 0.4                0.5
# 6              .            .                 0.3                0.6
# 7            0.1          0.3                   .                  .
# 8            0.1          0.2                   2                3.9
# 9           -0.6          0.6                  -4                3.8
# 10          -0.5          0.5                  -1                1.5
# 11             .            .                  -1                1.5
# 12          -0.5          0.5                   .                  .
# 13          -0.2          0.3                   .                  .
# 14             .            .                -0.3                0.6
# 15             .            .                -2.6                3.4
# 16             .            .                   .                  .
# 17             .            .                   .                  .
# 18           NaN          NaN                 NaN                NaN
# 19           NaN          NaN                 NaN                NaN
# 20           NaN          NaN                 NaN                NaN
# 21           NaN          NaN                 NaN                NaN
# 22           NaN          NaN                 NaN                NaN
# 23           NaN          NaN                 NaN                NaN
# 24           NaN          NaN                 NaN                NaN
# 25           NaN          NaN                 NaN                NaN
# 26           NaN          NaN                 NaN                NaN
# 27           NaN          NaN                 NaN                NaN
# 28           NaN          NaN                 NaN                NaN
# 29           NaN          NaN                 NaN                NaN
# 30           NaN          NaN                 NaN                NaN
# 31           NaN          NaN                 NaN                NaN
# 32           NaN          NaN                 NaN                NaN
# 33           NaN          NaN                 NaN                NaN
# 34           NaN          NaN                 NaN                NaN
# 35           NaN          NaN                 NaN                NaN
# 36           NaN          NaN                 NaN                NaN
#
#    CIT New Zealand EST CIT New Zealand CI CIT Nigeria EST CIT Nigeria CI  \
# 0                  3.4                1.7             6.1            3.7
# 1                  2.8                1.6             0.7            0.8
# 2                  1.4                1.2             0.7            0.8
# 3                  1.4                0.9               .              .
# 4                    .                  .               1              1
# 5                    .                  .             4.4            3.5
# 6                    .                  .               .              .
# 7                  0.6                0.6               .              .
# 8                    .                  .               .              .
# 9                 -2.1                1.6              -1            0.9
# 10                -0.8                0.7            -0.6            0.7
# 11                -0.6                0.6               .              .
# 12                -0.2                0.3            -0.6            0.7
# 13                   .                  .               .              .
# 14                -0.3                0.6            -0.4            0.5
# 15                -0.4                0.6               .              .
# 16                -0.6                1.1               .              .
# 17                   .                  .               .              .
# 18                 NaN                NaN             NaN            NaN
# 19                 NaN                NaN             NaN            NaN
# 20                 NaN                NaN             NaN            NaN
# 21                 NaN                NaN             NaN            NaN
# 22                 NaN                NaN             NaN            NaN
# 23                 NaN                NaN             NaN            NaN
# 24                 NaN                NaN             NaN            NaN
# 25                 NaN                NaN             NaN            NaN
# 26                 NaN                NaN             NaN            NaN
# 27                 NaN                NaN             NaN            NaN
# 28                 NaN                NaN             NaN            NaN
# 29                 NaN                NaN             NaN            NaN
# 30                 NaN                NaN             NaN            NaN
# 31                 NaN                NaN             NaN            NaN
# 32                 NaN                NaN             NaN            NaN
# 33                 NaN                NaN             NaN            NaN
# 34                 NaN                NaN             NaN            NaN
# 35                 NaN                NaN             NaN            NaN
# 36                 NaN                NaN             NaN            NaN
#
#    CIT Norway EST CIT Norway CI
# 0             3.4           2.6
# 1             0.2           0.3
# 2               .             .
# 3             0.2           0.3
# 4             0.3           0.6
# 5             2.9           2.5
# 6               .             .
# 7               .             .
# 8               .             .
# 9              -1             1
# 10           -0.4           0.5
# 11           -0.2           0.4
# 12           -0.2           0.4
# 13              .             .
# 14           -0.1           0.3
# 15           -0.4           0.7
# 16           -0.1           0.2
# 17              .             .
# 18            NaN           NaN
# 19            NaN           NaN
# 20            NaN           NaN
# 21            NaN           NaN
# 22            NaN           NaN
# 23            NaN           NaN
# 24            NaN           NaN
# 25            NaN           NaN
# 26            NaN           NaN
# 27            NaN           NaN
# 28            NaN           NaN
# 29            NaN           NaN
# 30            NaN           NaN
# 31            NaN           NaN
# 32            NaN           NaN
# 33            NaN           NaN
# 34            NaN           NaN
# 35            NaN           NaN
# 36            NaN           NaN
#
# [37 rows x 87 columns]

# %%
observations = df1.iloc[:, 2:]
observations.head()
# Out:
#                       Row Label  CIT All EST  CIT All CI CIT Germany EST  \
# 0           INFLOW, All reasons        526.6        34.4             9.1
# 1  INFLOW, Work related reasons        263.0        23.6             4.3
# 2          INFLOW, Definite job        172.3        19.0             3.2
# 3      INFLOW, Looking for work         90.6        14.0             1.1
# 4     INFLOW, Accompany or Join         83.3        12.4             0.7
#
#   CIT Germany CI CIT Ghana EST CIT Ghana CI CIT Greece EST CIT Greece CI  \
# 0            3.7           0.7          0.6            4.8           3.2
# 1            2.5           0.2          0.3            2.4             2
# 2              2           0.2          0.3            1.6           1.7
# 3            1.4             .            .            0.8           1.1
# 4            0.8           0.4          0.4            0.6           1.3
#
#   CIT Guinea EST      ...      CIT Nepal EST CIT Nepal CI CIT Netherlands EST  \
# 0            0.1      ...                1.4          0.8                   6
# 1              .      ...                0.1          0.2                 3.2
# 2              .      ...                0.1          0.2                 2.2
# 3              .      ...                  .            .                 1.1
# 4            0.1      ...                  1          0.7                 0.2
#
#   CIT Netherlands CI CIT New Zealand EST CIT New Zealand CI CIT Nigeria EST  \
# 0                4.8                 3.4                1.7             6.1
# 1                2.8                 2.8                1.6             0.7
# 2                2.3                 1.4                1.2             0.7
# 3                1.5                 1.4                0.9               .
# 4                0.3                   .                  .               1
#
#   CIT Nigeria CI CIT Norway EST CIT Norway CI
# 0            3.7            3.4           2.6
# 1            0.8            0.2           0.3
# 2            0.8              .             .
# 3              .            0.2           0.3
# 4              1            0.3           0.6
#
# [5 rows x 85 columns]

# %%
new_table = pd.melt(observations,
                       ["Row Label"],
                       var_name="Column label",
                       value_name="Value")

# %%
new_table.head(50)
# Out:
#                         Row Label Column label  Value
# 0             INFLOW, All reasons  CIT All EST  526.6
# 1    INFLOW, Work related reasons  CIT All EST    263
# 2            INFLOW, Definite job  CIT All EST  172.3
# 3        INFLOW, Looking for work  CIT All EST   90.6
# 4       INFLOW, Accompany or Join  CIT All EST   83.3
# 5            INFLOW, Formal study  CIT All EST    132
# 6      INFLOW, Going home to live  CIT All EST   19.1
# 7           INFLOW, Other reasons  CIT All EST   17.1
# 8        INFLOW, No reason stated  CIT All EST     12
# 9            OUTFLOW, All reasons  CIT All EST -315.8
# 10  OUTFLOW, Work related reasons  CIT All EST   -171
# 11          OUTFLOW, Definite job  CIT All EST   -110
# 12      OUTFLOW, Looking for work  CIT All EST  -61.1
# 13     OUTFLOW, Accompany or Join  CIT All EST  -23.9
# 14          OUTFLOW, Formal study  CIT All EST  -19.8
# 15    OUTFLOW, Going home to live  CIT All EST  -53.2
# 16         OUTFLOW, Other reasons  CIT All EST  -22.8
# 17      OUTFLOW, No reason stated  CIT All EST  -24.9
# 18                            NaN  CIT All EST    NaN
# 19                            NaN  CIT All EST    NaN
# 20                            NaN  CIT All EST    NaN
# 21                            NaN  CIT All EST    NaN
# 22                            NaN  CIT All EST    NaN
# 23                            NaN  CIT All EST    NaN
# 24                            NaN  CIT All EST    NaN
# 25                            NaN  CIT All EST    NaN
# 26                            NaN  CIT All EST    NaN
# 27                            NaN  CIT All EST    NaN
# 28                            NaN  CIT All EST    NaN
# 29                            NaN  CIT All EST    NaN
# 30                            NaN  CIT All EST    NaN
# 31                            NaN  CIT All EST    NaN
# 32                            NaN  CIT All EST    NaN
# 33                            NaN  CIT All EST    NaN
# 34                            NaN  CIT All EST    NaN
# 35                            NaN  CIT All EST    NaN
# 36                            NaN  CIT All EST    NaN
# 37            INFLOW, All reasons   CIT All CI   34.4
# 38   INFLOW, Work related reasons   CIT All CI   23.6
# 39           INFLOW, Definite job   CIT All CI     19
# 40       INFLOW, Looking for work   CIT All CI     14
# 41      INFLOW, Accompany or Join   CIT All CI   12.4
# 42           INFLOW, Formal study   CIT All CI   17.9
# 43     INFLOW, Going home to live   CIT All CI    9.3
# 44          INFLOW, Other reasons   CIT All CI    5.2
# 45       INFLOW, No reason stated   CIT All CI    6.1
# 46           OUTFLOW, All reasons   CIT All CI     23
# 47  OUTFLOW, Work related reasons   CIT All CI   15.1
# 48          OUTFLOW, Definite job   CIT All CI   12.7
# 49      OUTFLOW, Looking for work   CIT All CI    8.1

# %%
new_table.shape
# Out:
# (3108, 3)

# %%
new_table.dropna(inplace=True)

# %%
new_table = new_table[new_table['Value'] != '.']

# %%
new_table = new_table[new_table['Value'] != '0']

# %%
new_table.head(50)
# Out:
#                         Row Label     Column label  Value
# 0             INFLOW, All reasons      CIT All EST  526.6
# 1    INFLOW, Work related reasons      CIT All EST    263
# 2            INFLOW, Definite job      CIT All EST  172.3
# 3        INFLOW, Looking for work      CIT All EST   90.6
# 4       INFLOW, Accompany or Join      CIT All EST   83.3
# 5            INFLOW, Formal study      CIT All EST    132
# 6      INFLOW, Going home to live      CIT All EST   19.1
# 7           INFLOW, Other reasons      CIT All EST   17.1
# 8        INFLOW, No reason stated      CIT All EST     12
# 9            OUTFLOW, All reasons      CIT All EST -315.8
# 10  OUTFLOW, Work related reasons      CIT All EST   -171
# 11          OUTFLOW, Definite job      CIT All EST   -110
# 12      OUTFLOW, Looking for work      CIT All EST  -61.1
# 13     OUTFLOW, Accompany or Join      CIT All EST  -23.9
# 14          OUTFLOW, Formal study      CIT All EST  -19.8
# 15    OUTFLOW, Going home to live      CIT All EST  -53.2
# 16         OUTFLOW, Other reasons      CIT All EST  -22.8
# 17      OUTFLOW, No reason stated      CIT All EST  -24.9
# 37            INFLOW, All reasons       CIT All CI   34.4
# 38   INFLOW, Work related reasons       CIT All CI   23.6
# 39           INFLOW, Definite job       CIT All CI     19
# 40       INFLOW, Looking for work       CIT All CI     14
# 41      INFLOW, Accompany or Join       CIT All CI   12.4
# 42           INFLOW, Formal study       CIT All CI   17.9
# 43     INFLOW, Going home to live       CIT All CI    9.3
# 44          INFLOW, Other reasons       CIT All CI    5.2
# 45       INFLOW, No reason stated       CIT All CI    6.1
# 46           OUTFLOW, All reasons       CIT All CI     23
# 47  OUTFLOW, Work related reasons       CIT All CI   15.1
# 48          OUTFLOW, Definite job       CIT All CI   12.7
# 49      OUTFLOW, Looking for work       CIT All CI    8.1
# 50     OUTFLOW, Accompany or Join       CIT All CI    5.7
# 51          OUTFLOW, Formal study       CIT All CI    5.6
# 52    OUTFLOW, Going home to live       CIT All CI   12.7
# 53         OUTFLOW, Other reasons       CIT All CI    4.9
# 54      OUTFLOW, No reason stated       CIT All CI    7.2
# 74            INFLOW, All reasons  CIT Germany EST    9.1
# 75   INFLOW, Work related reasons  CIT Germany EST    4.3
# 76           INFLOW, Definite job  CIT Germany EST    3.2
# 77       INFLOW, Looking for work  CIT Germany EST    1.1
# 78      INFLOW, Accompany or Join  CIT Germany EST    0.7
# 79           INFLOW, Formal study  CIT Germany EST    2.5
# 81          INFLOW, Other reasons  CIT Germany EST    1.1
# 82       INFLOW, No reason stated  CIT Germany EST    0.5
# 83           OUTFLOW, All reasons  CIT Germany EST   -7.8
# 84  OUTFLOW, Work related reasons  CIT Germany EST   -2.1
# 86      OUTFLOW, Looking for work  CIT Germany EST   -2.1
# 87     OUTFLOW, Accompany or Join  CIT Germany EST   -0.4
# 88          OUTFLOW, Formal study  CIT Germany EST   -2.8
# 89    OUTFLOW, Going home to live  CIT Germany EST     -2

# %%
new_table.count()
# Out:
# Row Label       678
# Column label    678
# Value           678
# dtype: int64

# %%
# sourceFilename = 'column-labels-revised.csv'
# sourceFile = sourceFolder / sourceFilename
# sourceUrl = 'https://drive.google.com/uc?export=download&id=1G3tiDCLxNxyrQ95W94DXsHNMqBxv45NX'

# if not (sourceFile.exists() and sourceFile.is_file()):
#     response = requests.get(sourceUrl)
#     with open(sourceFile, 'wb') as f:
#         f.write(response.content)

# columns = pd.read_csv(sourceFile)

# %%
# sourceFilename = 'row-labels-revised.csv'
# sourceFile = sourceFolder / sourceFilename
# sourceUrl = 'https://drive.google.com/uc?export=download&id=1baA0s5L1PdbK0VPWgNde70yjGFSAeZpa'

# if not (sourceFile.exists() and sourceFile.is_file()):
#     response = requests.get(sourceUrl)
#     with open(sourceFile, 'wb') as f:
#         f.write(response.content)

# rows = pd.read_csv(sourceFile)

# %%
# columns.head()

# %%
# rows.head()

# %%
# new_table = pd.merge(new_table, columns, how = 'left', left_on = 'Column label', right_on = 'Original.Label')

# %%
# new_table.head()

# %%
# new_table = pd.merge(new_table, rows, how = 'left', left_on = 'Row Label', right_on = 'original')

# %%
new_table.head()
# Out:
#                       Row Label Column label  Value
# 0           INFLOW, All reasons  CIT All EST  526.6
# 1  INFLOW, Work related reasons  CIT All EST    263
# 2          INFLOW, Definite job  CIT All EST  172.3
# 3      INFLOW, Looking for work  CIT All EST   90.6
# 4     INFLOW, Accompany or Join  CIT All EST   83.3

# %%
new_table['Geography'] = 'K02000001'
new_table['Unit'] = 'People (thousands)'
new_table['Measure Type'] = 'Count'
new_table['Year'] = '2016'
new_table.tail()
# Out:
#                         Row Label   Column label Value  Geography  \
# 3082        OUTFLOW, Definite job  CIT Norway CI   0.4  K02000001
# 3083    OUTFLOW, Looking for work  CIT Norway CI   0.4  K02000001
# 3085        OUTFLOW, Formal study  CIT Norway CI   0.3  K02000001
# 3086  OUTFLOW, Going home to live  CIT Norway CI   0.7  K02000001
# 3087       OUTFLOW, Other reasons  CIT Norway CI   0.2  K02000001
#
#                     Unit Measure Type  Year
# 3082  People (thousands)        Count  2016
# 3083  People (thousands)        Count  2016
# 3085  People (thousands)        Count  2016
# 3086  People (thousands)        Count  2016
# 3087  People (thousands)        Count  2016

# %%
new_table.dtypes
# Out:
# Row Label       object
# Column label    object
# Value           object
# Geography       object
# Unit            object
# Measure Type    object
# Year            object
# dtype: object

# %%
new_table['Value'] = new_table['Value'].astype(int)

# %%
new_table['Year'] = new_table['Year'].astype(int)

# %%
new_table.count()
# Out:
# Row Label       678
# Column label    678
# Value           678
# Geography       678
# Unit            678
# Measure Type    678
# Year            678
# dtype: int64

# %%
new_table.head(5)
# Out:
#                       Row Label Column label  Value  Geography  \
# 0           INFLOW, All reasons  CIT All EST    526  K02000001
# 1  INFLOW, Work related reasons  CIT All EST    263  K02000001
# 2          INFLOW, Definite job  CIT All EST    172  K02000001
# 3      INFLOW, Looking for work  CIT All EST     90  K02000001
# 4     INFLOW, Accompany or Join  CIT All EST     83  K02000001
#
#                  Unit Measure Type  Year
# 0  People (thousands)        Count  2016
# 1  People (thousands)        Count  2016
# 2  People (thousands)        Count  2016
# 3  People (thousands)        Count  2016
# 4  People (thousands)        Count  2016

# %%
new_table = new_table[['Geography','Year','Row Label','Column label','Measure Type','Value','Unit']]

# %%
new_table
# Out:
#       Geography  Year                      Row Label    Column label  \
# 0     K02000001  2016            INFLOW, All reasons     CIT All EST
# 1     K02000001  2016   INFLOW, Work related reasons     CIT All EST
# 2     K02000001  2016           INFLOW, Definite job     CIT All EST
# 3     K02000001  2016       INFLOW, Looking for work     CIT All EST
# 4     K02000001  2016      INFLOW, Accompany or Join     CIT All EST
# 5     K02000001  2016           INFLOW, Formal study     CIT All EST
# 6     K02000001  2016     INFLOW, Going home to live     CIT All EST
# 7     K02000001  2016          INFLOW, Other reasons     CIT All EST
# 8     K02000001  2016       INFLOW, No reason stated     CIT All EST
# 9     K02000001  2016           OUTFLOW, All reasons     CIT All EST
# 10    K02000001  2016  OUTFLOW, Work related reasons     CIT All EST
# 11    K02000001  2016          OUTFLOW, Definite job     CIT All EST
# 12    K02000001  2016      OUTFLOW, Looking for work     CIT All EST
# 13    K02000001  2016     OUTFLOW, Accompany or Join     CIT All EST
# 14    K02000001  2016          OUTFLOW, Formal study     CIT All EST
# 15    K02000001  2016    OUTFLOW, Going home to live     CIT All EST
# 16    K02000001  2016         OUTFLOW, Other reasons     CIT All EST
# 17    K02000001  2016      OUTFLOW, No reason stated     CIT All EST
# 37    K02000001  2016            INFLOW, All reasons      CIT All CI
# 38    K02000001  2016   INFLOW, Work related reasons      CIT All CI
# 39    K02000001  2016           INFLOW, Definite job      CIT All CI
# 40    K02000001  2016       INFLOW, Looking for work      CIT All CI
# 41    K02000001  2016      INFLOW, Accompany or Join      CIT All CI
# 42    K02000001  2016           INFLOW, Formal study      CIT All CI
# 43    K02000001  2016     INFLOW, Going home to live      CIT All CI
# 44    K02000001  2016          INFLOW, Other reasons      CIT All CI
# 45    K02000001  2016       INFLOW, No reason stated      CIT All CI
# 46    K02000001  2016           OUTFLOW, All reasons      CIT All CI
# 47    K02000001  2016  OUTFLOW, Work related reasons      CIT All CI
# 48    K02000001  2016          OUTFLOW, Definite job      CIT All CI
# ...         ...   ...                            ...             ...
# 3001  K02000001  2016      INFLOW, Accompany or Join  CIT Nigeria CI
# 3002  K02000001  2016           INFLOW, Formal study  CIT Nigeria CI
# 3006  K02000001  2016           OUTFLOW, All reasons  CIT Nigeria CI
# 3007  K02000001  2016  OUTFLOW, Work related reasons  CIT Nigeria CI
# 3009  K02000001  2016      OUTFLOW, Looking for work  CIT Nigeria CI
# 3011  K02000001  2016          OUTFLOW, Formal study  CIT Nigeria CI
# 3034  K02000001  2016            INFLOW, All reasons  CIT Norway EST
# 3035  K02000001  2016   INFLOW, Work related reasons  CIT Norway EST
# 3037  K02000001  2016       INFLOW, Looking for work  CIT Norway EST
# 3038  K02000001  2016      INFLOW, Accompany or Join  CIT Norway EST
# 3039  K02000001  2016           INFLOW, Formal study  CIT Norway EST
# 3043  K02000001  2016           OUTFLOW, All reasons  CIT Norway EST
# 3044  K02000001  2016  OUTFLOW, Work related reasons  CIT Norway EST
# 3045  K02000001  2016          OUTFLOW, Definite job  CIT Norway EST
# 3046  K02000001  2016      OUTFLOW, Looking for work  CIT Norway EST
# 3048  K02000001  2016          OUTFLOW, Formal study  CIT Norway EST
# 3049  K02000001  2016    OUTFLOW, Going home to live  CIT Norway EST
# 3050  K02000001  2016         OUTFLOW, Other reasons  CIT Norway EST
# 3071  K02000001  2016            INFLOW, All reasons   CIT Norway CI
# 3072  K02000001  2016   INFLOW, Work related reasons   CIT Norway CI
# 3074  K02000001  2016       INFLOW, Looking for work   CIT Norway CI
# 3075  K02000001  2016      INFLOW, Accompany or Join   CIT Norway CI
# 3076  K02000001  2016           INFLOW, Formal study   CIT Norway CI
# 3080  K02000001  2016           OUTFLOW, All reasons   CIT Norway CI
# 3081  K02000001  2016  OUTFLOW, Work related reasons   CIT Norway CI
# 3082  K02000001  2016          OUTFLOW, Definite job   CIT Norway CI
# 3083  K02000001  2016      OUTFLOW, Looking for work   CIT Norway CI
# 3085  K02000001  2016          OUTFLOW, Formal study   CIT Norway CI
# 3086  K02000001  2016    OUTFLOW, Going home to live   CIT Norway CI
# 3087  K02000001  2016         OUTFLOW, Other reasons   CIT Norway CI
#
#      Measure Type  Value                Unit
# 0           Count    526  People (thousands)
# 1           Count    263  People (thousands)
# 2           Count    172  People (thousands)
# 3           Count     90  People (thousands)
# 4           Count     83  People (thousands)
# 5           Count    132  People (thousands)
# 6           Count     19  People (thousands)
# 7           Count     17  People (thousands)
# 8           Count     12  People (thousands)
# 9           Count   -315  People (thousands)
# 10          Count   -171  People (thousands)
# 11          Count   -110  People (thousands)
# 12          Count    -61  People (thousands)
# 13          Count    -23  People (thousands)
# 14          Count    -19  People (thousands)
# 15          Count    -53  People (thousands)
# 16          Count    -22  People (thousands)
# 17          Count    -24  People (thousands)
# 37          Count     34  People (thousands)
# 38          Count     23  People (thousands)
# 39          Count     19  People (thousands)
# 40          Count     14  People (thousands)
# 41          Count     12  People (thousands)
# 42          Count     17  People (thousands)
# 43          Count      9  People (thousands)
# 44          Count      5  People (thousands)
# 45          Count      6  People (thousands)
# 46          Count     23  People (thousands)
# 47          Count     15  People (thousands)
# 48          Count     12  People (thousands)
# ...           ...    ...                 ...
# 3001        Count      1  People (thousands)
# 3002        Count      3  People (thousands)
# 3006        Count      0  People (thousands)
# 3007        Count      0  People (thousands)
# 3009        Count      0  People (thousands)
# 3011        Count      0  People (thousands)
# 3034        Count      3  People (thousands)
# 3035        Count      0  People (thousands)
# 3037        Count      0  People (thousands)
# 3038        Count      0  People (thousands)
# 3039        Count      2  People (thousands)
# 3043        Count     -1  People (thousands)
# 3044        Count      0  People (thousands)
# 3045        Count      0  People (thousands)
# 3046        Count      0  People (thousands)
# 3048        Count      0  People (thousands)
# 3049        Count      0  People (thousands)
# 3050        Count      0  People (thousands)
# 3071        Count      2  People (thousands)
# 3072        Count      0  People (thousands)
# 3074        Count      0  People (thousands)
# 3075        Count      0  People (thousands)
# 3076        Count      2  People (thousands)
# 3080        Count      1  People (thousands)
# 3081        Count      0  People (thousands)
# 3082        Count      0  People (thousands)
# 3083        Count      0  People (thousands)
# 3085        Count      0  People (thousands)
# 3086        Count      0  People (thousands)
# 3087        Count      0  People (thousands)
#
# [678 rows x 7 columns]

# %%
destinationFolder = Path('out')
destinationFolder.mkdir(exist_ok=True, parents=True)

new_table.to_csv(destinationFolder / ('tidydata4.02C.csv'), index = False)

# %%
writeMetadata(metadata, 'ONS-LTIM-Passenger-survey-4.02C', 'Migration')

# %%
new_table.count()
# Out:
# Geography       678
# Year            678
# Row Label       678
# Column label    678
# Measure Type    678
# Value           678
# Unit            678
# dtype: int64
